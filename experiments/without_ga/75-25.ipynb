# %% [markdown]
# LOGISTIC REGRESSION

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
# Replace with your dataset path or URL if needed
df = pd.read_csv('heart.csv')  # commonly used Kaggle dataset

# Check basic info
print("Dataset Shape:", df.shape)
print(df.head())

# Split features and target
X = df.drop('target', axis=1)  # 'target' is usually the label for heart disease
y = df['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create logistic regression model
model = LogisticRegression(max_iter=1000)  # increase iterations if convergence warning
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate the model
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.7821011673151751
#
# Confusion Matrix:
#  [[ 94  38]
#  [ 18 107]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.71      0.77       132
#            1       0.74      0.86      0.79       125
#
#     accuracy                           0.78       257
#    macro avg       0.79      0.78      0.78       257
# weighted avg       0.79      0.78      0.78       257

# %% [markdown]
# SVM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('heart.csv')  # Replace with your dataset path if needed

# Basic info
print("Dataset Shape:", df.shape)
print(df.head())

# Features and target
X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create SVM model (you can change kernel='rbf', 'poly', etc.)
svm_model = SVC(kernel='linear')  # 'linear' is often good for classification tasks
svm_model.fit(X_train, y_train)

# Predict on test data
y_pred = svm_model.predict(X_test)

# Evaluation
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='YlGnBu')
plt.title('SVM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.7898832684824902
#
# Confusion Matrix:
#  [[ 96  36]
#  [ 18 107]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78       132
#            1       0.75      0.86      0.80       125
#
#     accuracy                           0.79       257
#    macro avg       0.80      0.79      0.79       257
# weighted avg       0.80      0.79      0.79       257

# %% [markdown]
# KNN

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('heart.csv')  # Make sure 'target' column exists

# Basic info
print("Dataset Shape:", df.shape)
print(df.head())

# Split into features and target
X = df.drop('target', axis=1)
y = df['target']

# Normalize the features (important for KNN)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# Create KNN model (you can tune n_neighbors)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

# Predict
y_pred = knn_model.predict(X_test)

# Evaluate
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='BuPu')
plt.title('KNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.8287937743190662
#
# Confusion Matrix:
#  [[107  25]
#  [ 19 106]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       132
#            1       0.81      0.85      0.83       125
#
#     accuracy                           0.83       257
#    macro avg       0.83      0.83      0.83       257
# weighted avg       0.83      0.83      0.83       257

# %% [markdown]
# DECSION TREE

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('heart.csv')  # Make sure the 'target' column is present

# Basic info
print("Dataset Shape:", df.shape)
print(df.head())

# Split features and target
X = df.drop('target', axis=1)
y = df['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create Decision Tree model (can tune criterion='gini' or 'entropy')
dt_model = DecisionTreeClassifier(criterion='gini', random_state=42, max_depth=5)
dt_model.fit(X_train, y_train)

# Predict
y_pred = dt_model.predict(X_test)

# Evaluation
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='OrRd')
plt.title('Decision Tree Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Visualize the tree
plt.figure(figsize=(20, 10))
plot_tree(dt_model, feature_names=X.columns, class_names=['No Disease', 'Disease'], filled=True, rounded=True)
plt.title('Decision Tree Structure')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.8249027237354085
#
# Confusion Matrix:
#  [[ 93  39]
#  [  6 119]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.70      0.81       132
#            1       0.75      0.95      0.84       125
#
#     accuracy                           0.82       257
#    macro avg       0.85      0.83      0.82       257
# weighted avg       0.85      0.82      0.82       257

# %% [markdown]
# RANDOM FOREST

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('heart.csv')  # Check if 'target' column exists

# Overview
print("Dataset Shape:", df.shape)
print(df.head())

# Split into features and target
X = df.drop('target', axis=1)
y = df['target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, max_depth=6, random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred = rf_model.predict(X_test)

# Evaluation
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Greens')
plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Feature Importance
importances = rf_model.feature_importances_
features = X.columns
indices = np.argsort(importances)

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], align="center", color='teal')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.914396887159533
#
# Confusion Matrix:
#  [[118  14]
#  [  8 117]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       132
#            1       0.89      0.94      0.91       125
#
#     accuracy                           0.91       257
#    macro avg       0.91      0.91      0.91       257
# weighted avg       0.92      0.91      0.91       257

# %% [markdown]
# NAIVE BAYES

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('heart.csv')  # Make sure 'target' column exists

# Quick look
print("Dataset Shape:", df.shape)
print(df.head())

# Features and target
X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create and train Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Predict
y_pred = nb_model.predict(X_test)

# Evaluate
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Purples')
plt.title('Naive Bayes Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.7937743190661478
#
# Confusion Matrix:
#  [[ 96  36]
#  [ 17 108]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.73      0.78       132
#            1       0.75      0.86      0.80       125
#
#     accuracy                           0.79       257
#    macro avg       0.80      0.80      0.79       257
# weighted avg       0.80      0.79      0.79       257

# %% [markdown]
# XG BOOST

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost import XGBClassifier, plot_importance
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('heart.csv')  # Make sure the file and 'target' column are present

# Quick overview
print("Dataset Shape:", df.shape)
print(df.head())

# Features and target
X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Initialize XGBoost classifier
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

# Predict
y_pred = xgb_model.predict(X_test)

# Evaluation
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='coolwarm')
plt.title('XGBoost Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Feature importance plot
plt.figure(figsize=(10, 6))
plot_importance(xgb_model, importance_type='gain', show_values=False)
plt.title('Feature Importance - XGBoost')
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# Accuracy Score: 0.9883268482490273
#
# Confusion Matrix:
#  [[132   0]
#  [  3 122]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       132
#            1       1.00      0.98      0.99       125
#
#     accuracy                           0.99       257
#    macro avg       0.99      0.99      0.99       257
# weighted avg       0.99      0.99      0.99       257
# C:\Users\Anmol\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:50:41] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %% [markdown]
# LIGHT BGM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import lightgbm as lgb
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('heart.csv')  # Ensure the 'target' column is present

# Preview
print("Dataset Shape:", df.shape)
print(df.head())

# Features and target
X = df.drop('target', axis=1)
y = df['target']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create and train LightGBM model
lgb_model = lgb.LGBMClassifier(random_state=42)
lgb_model.fit(X_train, y_train)

# Predict
y_pred = lgb_model.predict(X_test)

# Evaluation
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='YlOrBr')
plt.title('LightGBM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Feature importance plot
lgb.plot_importance(lgb_model, max_num_features=10, importance_type='gain', figsize=(10, 6))
plt.title("Top 10 Feature Importances - LightGBM")
plt.show()
# Out:
# Dataset Shape: (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# [LightGBM] [Info] Number of positive: 401, number of negative: 367
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 357
# [LightGBM] [Info] Number of data points in the train set: 768, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.522135 -> initscore=0.088600
# [LightGBM] [Info] Start training from score 0.088600
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Accuracy Score: 0.9883268482490273
#
# Confusion Matrix:
#  [[132   0]
#  [  3 122]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       132
#            1       1.00      0.98      0.99       125
#
#     accuracy                           0.99       257
#    macro avg       0.99      0.99      0.99       257
# weighted avg       0.99      0.99      0.99       257

# %% [markdown]
# CNN

# %%
# 📦 Imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
import numpy as np
import random
import tensorflow as tf  # If using TensorFlow

# Set the random seed value
seed_value = 42

# For random library (Python's built-in random)
random.seed(seed_value)

# For numpy
np.random.seed(seed_value)

# For TensorFlow (if you're using it)
tf.random.set_seed(seed_value)

# 📥 Load dataset
df = pd.read_csv('heart.csv')  # Ensure 'target' column exists

# ✅ Feature & Target Split
X = df.drop('target', axis=1)
y = df['target']

# 🔄 Standardize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 🔁 Reshape for CNN: (samples, features, 1)
X_scaled = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# 🧠 Build CNN Model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(X_scaled.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))  # Binary output

# ⚙️ Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# ⏳ Train Model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 🔮 Predict
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# 📊 Evaluation
print("\n✅ Accuracy Score:", accuracy_score(y_test, y_pred))
print("\n🧾 Classification Report:\n", classification_report(y_test, y_pred))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# 🔥 Confusion Matrix Plot
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title('CNN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# 📈 Accuracy & Loss Curves
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Val Accuracy', color='blue')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Val Loss', color='orange')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Anmol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6676 - loss: 0.6064 - val_accuracy: 0.7899 - val_loss: 0.4424
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8080 - loss: 0.4270 - val_accuracy: 0.7860 - val_loss: 0.4319
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7848 - loss: 0.4256 - val_accuracy: 0.7821 - val_loss: 0.4291
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8170 - loss: 0.3861 - val_accuracy: 0.7743 - val_loss: 0.4261
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8280 - loss: 0.3770 - val_accuracy: 0.7782 - val_loss: 0.4235
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8435 - loss: 0.3659 - val_accuracy: 0.7782 - val_loss: 0.4226
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8217 - loss: 0.3698 - val_accuracy: 0.7899 - val_loss: 0.4057
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8396 - loss: 0.3570 - val_accuracy: 0.7860 - val_loss: 0.4034
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8415 - loss: 0.3538 - val_accuracy: 0.7938 - val_loss: 0.3955
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8600 - loss: 0.3258 - val_accuracy: 0.7977 - val_loss: 0.3830
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8584 - loss: 0.3216 - val_accuracy: 0.8016 - val_loss: 0.3762
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import numpy as np
import random
import tensorflow as tf  # If using TensorFlow

# Set the random seed value
seed_value = 42

# For random library (Python's built-in random)
random.seed(seed_value)

# For numpy
np.random.seed(seed_value)

# For TensorFlow (if you're using it)
tf.random.set_seed(seed_value)

# 📥 Load Dataset
df = pd.read_csv('heart.csv')  # Ensure the dataset contains a 'target' column

# ✅ Split Features and Target
X = df.drop('target', axis=1)
y = df['target']

# 🔄 Standardize Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 🔁 Reshape for LSTM: (samples, timesteps, features)
X_scaled = X_scaled.reshape(X_scaled.shape[0], X_scaled.shape[1], 1)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# 🧠 Build LSTM Model
model = Sequential()
model.add(LSTM(64, input_shape=(X_scaled.shape[1], 1), return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# ⚙️ Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# ⏳ Train Model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 🔮 Make Predictions
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# 📊 Evaluation Metrics
print("\n✅ Accuracy Score:", accuracy_score(y_test, y_pred))
print("\n🧾 Classification Report:\n", classification_report(y_test, y_pred))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# 📌 Confusion Matrix Heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Purples')
plt.title('LSTM Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy and Loss Over Epochs
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='blue')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Anmol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7094 - loss: 0.6561 - val_accuracy: 0.6498 - val_loss: 0.6371
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7486 - loss: 0.5801 - val_accuracy: 0.7004 - val_loss: 0.6304
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7478 - loss: 0.5424 - val_accuracy: 0.6887 - val_loss: 0.6082
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7394 - loss: 0.5351 - val_accuracy: 0.7198 - val_loss: 0.5762
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7492 - loss: 0.5290 - val_accuracy: 0.7121 - val_loss: 0.5692
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7401 - loss: 0.5192 - val_accuracy: 0.7354 - val_loss: 0.5499
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7522 - loss: 0.5149 - val_accuracy: 0.7315 - val_loss: 0.5453
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7588 - loss: 0.5098 - val_accuracy: 0.7354 - val_loss: 0.5383
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7536 - loss: 0.5031 - val_accuracy: 0.7354 - val_loss: 0.5299
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.4887 - val_accuracy: 0.7315 - val_loss: 0.5232
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7684 - loss: 0.4809 - val_accuracy: 0.7393 - val_loss: 0.5229
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7585 - loss: 0.4833 - val_accuracy: 0.7393 - val_loss: 0.5154
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7712 - loss: 0.4726 - val_accuracy: 0.7549 - val_loss: 0.5088
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7807 - loss: 0.4657 - val_accuracy: 0.7432 - val_loss: 0.5056
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7897 - loss: 0.4504 - val_accuracy: 0.7510 - val_loss: 0.5013
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7869 - loss: 0.4569 - val_accuracy: 0.7432 - val_loss: 0.4962
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7794 - loss: 0.4375 - val_accuracy: 0.7626 - val_loss: 0.4802
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7884 - loss: 0.4318 - val_accuracy: 0.7510 - val_loss: 0.4814
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7756 - loss: 0.4240 - val_accuracy: 0.7626 - val_loss: 0.4782
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7897 - loss: 0.4192 - val_accuracy: 0.7782 - val_loss: 0.4758
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7987 - loss: 0.4167 - val_accuracy: 0.7743 - val_loss: 0.4734
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7975 - loss: 0.4125 - val_accuracy: 0.7821 - val_loss: 0.4707
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8036 - loss: 0.3948 - val_accuracy: 0.7860 - val_loss: 0.4762
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8117 - loss: 0.3950 - val_accuracy: 0.7860 - val_loss: 0.4637
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8138 - loss: 0.3930 - val_accuracy: 0.7860 - val_loss: 0.4679
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8143 - loss: 0.3854 - val_accuracy: 0.8054 - val_loss: 0.4525
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.3748 - val_accuracy: 0.7977 - val_loss: 0.4327
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8322 - loss: 0.3708 - val_accuracy: 0.8132 - val_loss: 0.4258
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8357 - loss: 0.3509 - val_accuracy: 0.8132 - val_loss: 0.4204
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8377 - loss: 0.3418 - val_accuracy: 0.8171 - val_loss: 0.4042
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8239 - loss: 0.3773 - val_accuracy: 0.7899 - val_loss: 0.4340
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8367 - loss: 0.3458 - val_accuracy: 0.8054 - val_loss: 0.4169
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8523 - loss: 0.3354 - val_accuracy: 0.8132 - val_loss: 0.3929
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8740 - loss: 0.3105 - val_accuracy: 0.8132 - val_loss: 0.3531
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8675 - loss: 0.2907 - val_accuracy: 0.8210 - val_loss: 0.3558
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8716 - loss: 0.2862 - val_accuracy: 0.8366 - val_loss: 0.3231
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8808 - loss: 0.2898 - val_accuracy: 0.8521 - val_loss: 0.2948
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8945 - loss: 0.2587 - val_accuracy: 0.8716 - val_loss: 0.2838
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8947 - loss: 0.2624 - val_accuracy: 0.8599 - val_loss: 0.2681
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.2257 - val_accuracy: 0.9027 - val_loss: 0.2362
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9143 - loss: 0.2258 - val_accuracy: 0.8677 - val_loss: 0.2505
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9070 - loss: 0.2371 - val_accuracy: 0.8988 - val_loss: 0.2183
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9255 - loss: 0.2251 - val_accuracy: 0.9105 - val_loss: 0.2159
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9357 - loss: 0.1784 - val_accuracy: 0.9144 - val_loss: 0.1824
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.1811 - val_accuracy: 0.9183 - val_loss: 0.1660
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9424 - loss: 0.1592 - val_accuracy: 0.9222 - val_loss: 0.1874
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.1749 - val_accuracy: 0.9377 - val_loss: 0.1540
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9408 - loss: 0.1646 - val_accuracy: 0.9183 - val_loss: 0.1695
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9585 - loss: 0.1388 - val_accuracy: 0.9494 - val_loss: 0.1268
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9444 - loss: 0.1376 - val_accuracy: 0.9300 - val_loss: 0.1544
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
#
# ✅ Accuracy Score: 0.9299610894941635
#
# 🧾 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       132
#            1       0.93      0.93      0.93       125
#
#     accuracy                           0.93       257
#    macro avg       0.93      0.93      0.93       257
# weighted avg       0.93      0.93      0.93       257
#
#
# 🧱 Confusion Matrix:
#  [[123   9]
#  [  9 116]]

# %% [markdown]
# MLP

# %%
# 📦 Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import numpy as np
import random
import tensorflow as tf  # If using TensorFlow

# Set the random seed value
seed_value = 42

# For random library (Python's built-in random)
random.seed(seed_value)

# For numpy
np.random.seed(seed_value)

# For TensorFlow (if you're using it)
tf.random.set_seed(seed_value)

# 📥 Load Dataset
df = pd.read_csv('heart.csv')  # Ensure the dataset contains a 'target' column

# ✅ Split Features and Target
X = df.drop('target', axis=1)
y = df['target']

# 🔄 Standardize Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=42)

# 🧠 Build MLP Model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_scaled.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# ⚙️ Compile Model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# ⏳ Train Model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# 🔮 Make Predictions
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# 📊 Evaluation Metrics
print("\n✅ Accuracy Score:", accuracy_score(y_test, y_pred))
print("\n🧾 Classification Report:\n", classification_report(y_test, y_pred))
print("\n🧱 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# 📌 Confusion Matrix Heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Greens')
plt.title('MLP Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# 📈 Accuracy and Loss Over Epochs
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='green')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='blue')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\Anmol\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6760 - loss: 0.6096 - val_accuracy: 0.7860 - val_loss: 0.4239
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.4071 - val_accuracy: 0.8016 - val_loss: 0.3922
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8462 - loss: 0.3651 - val_accuracy: 0.8016 - val_loss: 0.3825
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8665 - loss: 0.3367 - val_accuracy: 0.8132 - val_loss: 0.3682
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8827 - loss: 0.3117 - val_accuracy: 0.8327 - val_loss: 0.3543
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8737 - loss: 0.3165 - val_accuracy: 0.8405 - val_loss: 0.3331
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8862 - loss: 0.2712 - val_accuracy: 0.8444 - val_loss: 0.3261
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8986 - loss: 0.2675 - val_accuracy: 0.8716 - val_loss: 0.3163
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8892 - loss: 0